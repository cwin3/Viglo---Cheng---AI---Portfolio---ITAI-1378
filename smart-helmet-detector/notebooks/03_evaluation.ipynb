# %%
# 03_evaluation.ipynb

# 1. Setup
# !pip install ultralytics
from ultralytics import YOLO
from IPython.display import Image, display

# ---------------------------------------------------------
# 2. VALIDATION
# ---------------------------------------------------------
# Load the model you just trained
# If running this immediately after training:
model_path = "runs/detect/helmet_detector_model/weights/best.pt"
# If running later, upload your best.pt and change path:
# model_path = "best.pt"

model = YOLO(model_path)

print("Running Validation on Test Set...")
metrics = model.val()

# ---------------------------------------------------------
# 3. PRINT METRICS
# ---------------------------------------------------------
print("\n--- RESULTS ---")
print(f"mAP50 (Accuracy): {metrics.box.map50:.3f}")
print(f"mAP50-95: {metrics.box.map:.3f}")
print(f"Precision: {metrics.box.mp:.3f}")
print(f"Recall: {metrics.box.mr:.3f}")

# ---------------------------------------------------------
# 4. SHOW CONFUSION MATRIX & CURVES
# ---------------------------------------------------------
# Ultralytics automatically saves these plots in the validation run folder
import glob

# Find the latest validation folder
latest_val = max(glob.glob('runs/detect/val*'), key=os.path.getmtime)
print(f"Showing plots from: {latest_val}")

print("Confusion Matrix:")
display(Image(filename=f'{latest_val}/confusion_matrix.png'))

print("F1 Confidence Curve:")
display(Image(filename=f'{latest_val}/F1_curve.png'))

print("Validation Batch Predictions:")
display(Image(filename=f'{latest_val}/val_batch0_pred.jpg'))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.1 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-931314492.py in <cell line: 0>()
#      15 # model_path = "best.pt"
#      16
# ---> 17 model = YOLO(model_path)
#      18
#      19 print("Running Validation on Test Set...")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      74         else:
#      75             # Continue with default YOLO initialization
# ...
